# %%
import olexpy._olexpy as olexpy

# %%
dir(olexpy)
# Out:
# ['PreprocessHtml',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__']

# %%
with open("h3-refine_NoSpherA2-extras.htm") as f:
    print(olexpy.PreprocessHtml(f.read()))
# Out:
# <ignore test="not(spy.GetParam('snum.NoSpherA2.Calculate'))">
#  <tr align="left" name="SNUM_REFINEMENT_NSFF" width="100%">
#   <td colspan="#colspan">
#    <table border="0" cellpadding="0" cellspacing="0" width="100%" xbgcolor="#ffaaaa">
#     <tr xbgcolor="#ffffaa">
#      <tr bgcolor="GetVar(HtmlTableGroupBgColour)">
#       <!-- #include tool-help-first-column gui/blocks/tool-help-first-column.htm;help_ext=NoSpherA2_Quick_Buttons;1 -->
#       <b>
#        $spy.NoSpherA2.make_quick_button_gui()
#       </b>
#      </tr>
#     </tr>
#    </table>
#   </td>
#   <tr align="left" name="SNUM_REFINEMENT_NSFF" width="100%">
#    <td colspan="#colspan">
#     <table border="0" cellpadding="0" cellspacing="0" width="100%" xbgcolor="#ffaaaa">
#      <tr xbgcolor="#ffffaa">
#       <tr bgcolor="GetVar(HtmlTableGroupBgColour)">
#        <!-- #include tool-help-first-column gui/blocks/tool-help-first-column.htm;help_ext=NoSpherA2_Options_1;1 -->
#        <td align="left" width="22%">
# ...
